# %%
import csv 
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %%
url1 = 'https://www.udemy.com/'
url = 'https://www.w3resource.com/'

# %%
res = requests.get(url=url)
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup
# Out:
# ﻿<!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="/assets/mdl/material.min.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/mdl/additional.css" rel="stylesheet" type="text/css"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
# <link href="//www.w3resource.com/images/favicon.png" rel="shortcut icon"/>
# <title>Web development tutorials | w3resource</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
# <meta content="Web development tutorials on HTML, CSS, JS, PHP, SQL, MySQL, PostgreSQL, MongoDB, JSON and more." name="description"/>
# <meta content="web development tutorials from w3resource" property="og:title">
# <meta content="Web development tutorials on HTML, CSS, JS, PHP, SQL, MySQL, PostgreSQL, MongoDB, JSON and more." property="og:description">
# <meta content="tutorial" property="og:type">
# ...

# %%
title_header = soup.find('title')

# %%
if title_header is None:
    print("No Title present for :", url)
else:
    print("Title is present for :", url)
    print(' ')
    print(title_header)
# Out:
# Title is present for : https://www.w3resource.com/
#
# <title>Web development tutorials | w3resource</title>

# %%
import csv 
import requests 
from bs4 import BeautifulSoup

#url = 'https://www.udemy.com/'
url = 'https://www.w3resource.com/'

res = requests.get(url=url)
# res

soup = BeautifulSoup(res.text, 'html.parser')
# soup

title_header = soup.find('title')

if title_header is None:
    print("No Title present for :", url)
else:
    print("Title is present for :", url)
    print(' ')
    print(title_header)
    print(title_header.text)
# Out:
# Title is present for : https://www.w3resource.com/
#
# <title>Web development tutorials | w3resource</title>
# Web development tutorials | w3resource

# %%
url1 = 'http://images.google.com'

# %%
res = requests.get(url=url1)
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
title_header = soup.find('div', {'class':'pR49Ae gsfi'})

# %%
title_header
